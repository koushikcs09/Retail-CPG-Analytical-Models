# %%
#following are the libraries 
import numpy as np  # to perform a wide variety of mathematical operations on arrays.
import pandas as pd # comman lib and use for displaying dataframe 
import tweepy       #gives you a very convenient way to access the Twitter API with Python
import re          #provides support for Perl-like regular expressions in Python.
import matplotlib.pyplot as plt # data visualization and graphical plotting library for Python 
plt.style.use('fivethirtyeight') # type of graps
pd.set_option('display.max_colwidth', -1)
import datetime
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_7784\317671732.py:8: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# Calling Keys of Twitter API

# %%
# %run ./keys.ipynb  # runs Jupyter Notebook files

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret) # auth giving a user permissions to access a particular resource.
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth , wait_on_rate_limit= True) #open source Python package to access the Twitter API with Python

# %%
api = tweepy.API(auth)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
tweets = []
likes = []
time = []

search_term = '#Bitcoin'
 #Create a cursor 
    
for i in tweepy.Cursor(api.search_tweets, q= search_term, lang='en',until="2022-07-20", tweet_mode='extended').items(100):
    tweets.append(i.full_text)
    likes.append(i.favorite_count)
    time.append(i.created_at)
    
# just for 2000 tweets for now 

#store tweets in variable
#all_tweets= [tweet.full_text for tweet in tweets]

# %%
df= pd.DataFrame({'tweets':tweets, 'likes':likes, 'time':time})

# %%
pd.set_option('display.max_colwidth', None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87908 entries, 0 to 87907
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tweets  87908 non-null  object
#  1   likes   87908 non-null  object
#  2   time    87908 non-null  object
# dtypes: object(3)
# memory usage: 2.0+ MB

# %%
df.to_csv('Bitcooin6.csv')

# %%
from pyspark import F


file0 = "C:\\Users\\patel\\Downloads\\project\\crypto.csv"
file1 = "C:\\Users\\patel\\Downloads\\project\\crypto1.csv"
file2 = "C:\\Users\\patel\\Downloads\\project\\crypto2.csv"
file3 = "C:\\Users\\patel\\Downloads\\project\\crypto3.csv"
file4 = "C:\\Users\\patel\\Downloads\\project\\crypto4.csv"
file5 = "C:\\Users\\patel\\Downloads\\project\\crypto5.csv"
file6 = "C:\\Users\\patel\\Downloads\\project\\crypto6.csv"
file7 = "C:\\Users\\patel\\Downloads\\project\\crypto7.csv"
file8 = "C:\\Users\\patel\\Downloads\\project\\crypto8.csv"
file9 = "C:\\Users\\patel\\Downloads\\project\\crypto9.csv"
file12 = "C:\\Users\\patel\\Downloads\\project\\Bitcooin.csv"
file13 = "C:\\Users\\patel\\Downloads\\project\\Bitcooin6.csv"
file14 = "C:\\Users\\patel\\Downloads\\project\\Bitcooin7.csv"
file15 = "C:\\Users\\patel\\Downloads\\project\\Bitcooin8.csv"
file16 = "C:\\Users\\patel\\Downloads\\project\\Bitcooin11.csv"

# %%
df = pd.concat(
   map(pd.read_csv, [file0,file1, file2,file3,file4,file5,file6,file7,file8,file9,file12,file13,file14,file15,file16]), ignore_index=True)

# %%
df
# Out:
#        Unnamed: 0  \
# 0       0
# 1       1
# 2       2
# 3       3
# 4       4
# ...    ..
# 128003  9995
# 128004  9996
# 128005  9997
# 128006  9998
# 128007  9999
#
#                                                                                                                                                                                                                                                  tweets  \
# 0       RT @MARBLEXofficial: MBX with Consensus 2022✨ Presents #Marblex Giveaway Event! Please check the details🔥\n📆Event Period : June 9th to 12th…
# 1       Aside of #crypto it’s getting real out here the gas the food on the table the bills going up they out here sucking us dry of every dollar I got kids and a wife to take care of fr got me over here thinking  man  #economy #recession #America
# 2       RT @OfficialTravlad: I will send $1,000 to someone that retweets and is following @rovercrc and myself in the next 48hrs.\n\nHe is also givin…
# ...

# %%
df.to_csv('Proect_dataset.csv')

# %%
df.head(5)
df
# Out:
#        Unnamed: 0  \
# 0       0
# 1       1
# 2       2
# 3       3
# 4       4
# ...    ..
# 128003  9995
# 128004  9996
# 128005  9997
# 128006  9998
# 128007  9999
#
#                                                                                                                                                                                                                                                  tweets  \
# 0       RT @MARBLEXofficial: MBX with Consensus 2022✨ Presents #Marblex Giveaway Event! Please check the details🔥\n📆Event Period : June 9th to 12th…
# 1       Aside of #crypto it’s getting real out here the gas the food on the table the bills going up they out here sucking us dry of every dollar I got kids and a wife to take care of fr got me over here thinking  man  #economy #recession #America
# 2       RT @OfficialTravlad: I will send $1,000 to someone that retweets and is following @rovercrc and myself in the next 48hrs.\n\nHe is also givin…
# ...

# %%
del df['Unnamed: 0']

# %%
df.to_csv('Proect_dataset.csv')

# %%
df.to_csv('Proect_dataset.csv')

# %%
df
# Out:
#                                                                                                                                                                                                                                                  tweets  \
# 0       RT @MARBLEXofficial: MBX with Consensus 2022✨ Presents #Marblex Giveaway Event! Please check the details🔥\n📆Event Period : June 9th to 12th…
# 1       Aside of #crypto it’s getting real out here the gas the food on the table the bills going up they out here sucking us dry of every dollar I got kids and a wife to take care of fr got me over here thinking  man  #economy #recession #America
# 2       RT @OfficialTravlad: I will send $1,000 to someone that retweets and is following @rovercrc and myself in the next 48hrs.\n\nHe is also givin…
# 3       RT @lisaownet: Thanks for the socks.\n\nMeet me at #Consensus2022 to discuss #Web3 #tokenization #tokenomics #blockchain #cryptocurrency #cry…
# ...
